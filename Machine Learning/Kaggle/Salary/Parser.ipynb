# %%
import numpy as np
import pandas as pd
import re
import time
import nltk

# %%
train = pd.read_csv("data/features-train.csv")
test = pd.read_csv("data/features-test.csv")

# %%
train
# Out:
#             Id                                              Title  \
# 0            0                 Chartered Senior Quantity Surveyor
# 1            1  Net Developer  VB / SQL  Central Manchester  *...
# 2            2  Desktop Support Administrator  Windows 7, Exch...
# 3            3                                Clinical Lead (RGN)
# 4            4        Charity Fundraisers  GET PAID TO SAVE LIVES
# 5            5                                    Lift Consultant
# 6            6                                  Measured Surveyor
# 7            7                                    Project Manager
# 8            8  Home Care Assistant / Home Carer Job in Maidst...
# 9            9     Exchange/Messaging Administrator x****  London
# 10          10                           Client Services Director
# 11          11                        Internal Dealership Manager
# 12          12                         Purchasing Admin Assistant
# ...

# %%
stemmer = nltk.stem.SnowballStemmer('english')

# %%
extra = nltk.corpus.stopwords.words('english')

# %%
tok = nltk.tokenize.RegexpTokenizer('\w+')

# %%
#Pars train data
_time = time.clock()
fTrain = open('train.txt', 'w')
i = 0
for array in train.values:
    fTrain.write(str(np.log(array[10])) +
        ' |title '    + ' '.join([stemmer.stem(w) for w in tok.tokenize('nan' if array[1] is np.nan else array[1]) if w.lower() not in extra]) +
        ' |fulldescr ' + ' '.join([stemmer.stem(w) for w in tok.tokenize(array[2]) if w.lower() not in extra]) +
        ' |loc ' + ' '.join([stemmer.stem(w) for w in tok.tokenize(array[4]) if w.lower() not in extra]) +
        ' |category ' + str(np.where(categorySet == str(array[8]))[0][0]) +
        '\n')
    i += 1
    if not i % 10000:
        print(i)
print(str(time.clock() - _time) + ' sec')
fTrain.close()
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 1149.196528 sec

# %%
#Pars test data
_time = time.clock()
fTest = open('test.txt', 'w')
i = 0
for array in test.values:
    fTest.write(
        ' |title '    + ' '.join([stemmer.stem(w) for w in tok.tokenize('nan' if array[1] is np.nan else array[1]) if w.lower() not in extra]) +
        ' |fulldescr ' + ' '.join([stemmer.stem(w) for w in tok.tokenize(array[2]) if w.lower() not in extra]) +
        ' |loc ' + ' '.join([stemmer.stem(w) for w in tok.tokenize(array[4]) if w.lower() not in extra]) +
        ' |category ' + str(np.where(categorySet == str(array[8]))[0][0]) +
        '\n')
    i += 1
    if not i % 10000:
        print(i)
print(str(time.clock() - _time) + ' sec')
fTest.close()
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 370.57485700000007 sec
